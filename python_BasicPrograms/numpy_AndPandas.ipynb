# %%
import numpy as np

# %%
my_list=[1,2,4,3,5,"Noor"]
my_array=np.array(my_list)

# %%
print(my_array)
print(type(my_array))
# Out:
# ['1' '2' '4' '3' '5' 'Noor']
# <class 'numpy.ndarray'>

# %%
import numpy as np
import pandas as pd

# %%
data={

 "Name":["NoorMustafa","Ali","alina"],
 "Age": [22,12,11],
"Gender":["MAle","MAle","Female"]

 }



df = pd.DataFrame(data)

# %%
df
# Out:
#           Name  Age  Gender
# 0  NoorMustafa   22    MAle
# 1          Ali   12    MAle
# 2        alina   11  Female
